# %%
import pandas as pd

# %%
# source: https://www.ercot.com/gridinfo/load/load_hist/index.html
df = pd.read_excel('/workspaces/mlops-zoomcamp-1/datasets/07/Native_Load_2025.xlsx',)

# %%
print(df.info())
print(df.describe(include='all'))
df.head
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2879 entries, 0 to 2878
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Hour Ending  2879 non-null   object
#  1   COAST        2879 non-null   float64
#  2   EAST         2879 non-null   float64
#  3   FWEST        2879 non-null   float64
#  4   NORTH        2879 non-null   float64
#  5   NCENT        2879 non-null   float64
#  6   SOUTH        2879 non-null   float64
#  7   SCENT        2879 non-null   float64
#  8   WEST         2879 non-null   float64
#  9   ERCOT        2879 non-null   float64
# dtypes: float64(9), object(1)
# memory usage: 225.1+ KB
# None
#              Hour Ending         COAST         EAST        FWEST        NORTH  \
# count               2879   2879.000000  2879.000000  2879.000000  2879.000000
# unique              2879           NaN          NaN          NaN          NaN
# ...

# %%
df_2024 = pd.read_excel('/workspaces/mlops-zoomcamp-1/datasets/07/Native_Load_2024.xlsx',)
df_2024.describe(include='all')
# Out:
#              Hour Ending         COAST         EAST        FWEST        NORTH  \
# count               8784   8784.000000  8784.000000  8784.000000  8784.000000
# unique              8784           NaN          NaN          NaN          NaN
# top     01/01/2024 01:00           NaN          NaN          NaN          NaN
# freq                   1           NaN          NaN          NaN          NaN
# mean                 NaN  14013.614785  1731.812815  6576.810420  1481.586241
# std                  NaN   2968.129654   413.585519   362.426233   275.100428
# min                  NaN   7128.496204  1032.913534  5232.990087   921.872585
# 25%                  NaN  11764.965016  1439.519643  6302.480454  1276.562426
# 50%                  NaN  13297.702024  1621.676404  6558.116470  1426.248341
# 75%                  NaN  15731.100881  1948.323567  6851.174834  1628.700639
# max                  NaN  23180.166742  3319.348544  7560.045901  2361.952902
#
# ...

# %%
# df_2024.info()
df_2024['Hour Ending'].max()
# Out:
# '12/31/2024 24:00'

# %%
import matplotlib.pyplot as plt
plt.bar(df_2024['Hour Ending'], df_2024['ERCOT'])
plt.bar(df['Hour Ending'], df['ERCOT'])
plt.show()
